# %% [markdown]
# # Your Title Here
#
# **Name**: Ivan Hughes
#
# **Website Link**: (your website link)

# %%
import pandas as pd
import numpy as np
from pathlib import Path

import plotly.express as px
pd.options.plotting.backend = 'plotly'

# from dsc80_utils import * # Feel free to uncomment and use this.

# %% [markdown]
# ## Step 1: Introduction

# %%
# TODO

# %% [markdown]
# ## Step 2: Data Cleaning and Exploratory Data Analysis

# %%
# TODO
df = pd.read_csv('
# Compare tempo distributions across genres (select top 5 genres)
top_genres = df['track_genre'].value_counts().head(5).index
df_subset = df[df['track_genre'].isin(top_genres)]

fig = px.box(df_subset, x='track_genre', y='tempo', 
             title='Tempo Distribution Across Top 5 Music Genres',
             labels={'tempo': 'Tempo (BPM)', 'track_genre': 'Genre'},
             color='track_genre')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18284\2348285434.py in <cell line: 4>()
#       2
#       3 # Compare tempo distributions across genres (select top 5 genres)
# ----> 4 top_genres = df['track_genre'].value_counts().head(5).index
#       5 df_subset = df[df['track_genre'].isin(top_genres)]
#       6
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Step 3: Assessment of Missingness

# %%
# TODO

# %% [markdown]
# ## Step 4: Hypothesis Testing

# %%
# TODO

# %% [markdown]
# ## Step 5: Framing a Prediction Problem

# %%
# TODO

# %% [markdown]
# ## Step 6: Baseline Model

# %%
# TODO

# %% [markdown]
# ## Step 7: Final Model

# %%
# TODO

# %% [markdown]
# ## Step 8: Fairness Analysis

# %%
# TODO
